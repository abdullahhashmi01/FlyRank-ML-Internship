# %% [markdown]
# # ML-04 — Search Intelligence Data Contract
#
# [![Open In Colab](https://colab.research.google.com/assets/colab-badge.svg)](https://colab.research.google.com/github/abdullahhashmi01/FlyRank-ML-Internship/blob/main/work/notebooks/w03_data_contract.ipynb?flush_cache=true)
#
# This skeleton is yours to fill. Work the sections **in order** — each one has a one-line hint. Simple words, honest numbers.
#
# > Working with an AI assistant? Tell it to read `skills/README.md` first and load the one skill this assignment names on its card.

# %% [markdown]
# ## 1. Unit of analysis + time window
#
# *One row = one what, over which dates? State it, then verify it below.*

# %%
# This cell is for CODE (numbers, a query, a check).
# Write your text answer in the cell ABOVE this one — typing sentences here breaks Run All.
import pandas as pd
from google.colab import files

uploaded = files.upload()
file_name = list(uploaded.keys())[0]

df = pd.read_csv(file_name)

print("Data loaded successfully")
print("Shape:", df.shape)
# Out:
#      <input type="file" id="files-ce3fbddf-2997-4f6e-8d94-73c2790fe7bd" name="files[]" multiple disabled
#         style="border:none" />
#      <output id="result-ce3fbddf-2997-4f6e-8d94-73c2790fe7bd">
#       Upload widget is only available when the cell has been executed in the
#       current browser session. Please rerun this cell to enable.
#       </output>
#       <script>// Copyright 2017 Google LLC
# //
# // Licensed under the Apache License, Version 2.0 (the "License");
# // you may not use this file except in compliance with the License.
# // You may obtain a copy of the License at
# //
# //      http://www.apache.org/licenses/LICENSE-2.0
# //
# // Unless required by applicable law or agreed to in writing, software
# // distributed under the License is distributed on an "AS IS" BASIS,
# // WITHOUT WARRANTIES OR CONDITIONS OF ANY KIND, either express or implied.
# // See the License for the specific language governing permissions and
# // limitations under the License.
#
# ...

# %% [markdown]
# ## 2. Fields: feature / label / context / excluded
#
# *Sort every field you plan to touch into these four buckets. Excluded needs a why.*

# %%
# This cell is for CODE (numbers, a query, a check).
# Write your text answer in the cell ABOVE this one — typing sentences here breaks Run All.
print("Rows:", len(df))
print("Columns:", len(df.columns))

print(
    "Unique clients:",
    df["client_id"].nunique()
)

print(
    "Unique content items:",
    df["content_id"].nunique()
)

duplicate_items = df.duplicated(
    subset=["client_id", "content_id"]
).sum()

print("Duplicate client-content rows:", duplicate_items)

date_columns = [
    column for column in df.columns
    if "date" in column.lower()
]

print("Available date fields:", date_columns)
# Out:
# Rows: 30000
# Columns: 44
# Unique clients: 32
# Unique content items: 30000
# Duplicate client-content rows: 0
# Available date fields: ['days_since_last_update']

# %% [markdown]
# ## 3. Verify it with queries (grain, counts, missing values, windows)
#
# *Every claim above gets a query cell here. A contract claim without a query next to it is a guess.*

# %%
# This cell is for CODE (numbers, a query, a check).
# Write your text answer in the cell ABOVE this one — typing sentences here breaks Run All.
feature_candidates = [
    "clicks",
    "impressions",
    "ctr",
    "avg_position",
    "engagement_rate",
    "scroll_rate",
    "ai_traffic_pct",
    "word_count",
    "content_type"
]

label_candidates = [
    "is_declining_label"
]

context_candidates = [
    "content_id",
    "client_id"
]

excluded_candidates = [
    "trend_direction",
    "trend_pct"
]

contract = pd.DataFrame({
    "bucket": [
        "Feature",
        "Label/proxy",
        "Context",
        "Excluded"
    ],
    "fields found in CSV": [
        [x for x in feature_candidates if x in df.columns],
        [x for x in label_candidates if x in df.columns],
        [x for x in context_candidates if x in df.columns],
        [x for x in excluded_candidates if x in df.columns]
    ]
})

contract
# Out:
#         bucket                                fields found in CSV
# 0      Feature  [ctr, avg_position, engagement_rate, scroll_ra...
# 1  Label/proxy                                                 []
# 2      Context                            [content_id, client_id]
# 3     Excluded                       [trend_direction, trend_pct]

# %% [markdown]
# ## 4. Data limits
#
# *What can this data never tell you? Unbalanced history, GSC-only early rows, window overlaps.*

# %%
# This cell is for CODE (numbers, a query, a check).
# Write your text answer in the cell ABOVE this one — typing sentences here breaks Run All.
print("Dataset shape:", df.shape)

print(
    "Duplicate grain:",
    df.duplicated(
        ["client_id", "content_id"]
    ).sum()
)

missing = pd.DataFrame({
    "column": df.columns,
    "missing_count": df.isna().sum(),
    "missing_percent": (
        df.isna().mean() * 100
    ).round(2)
})

display(
    missing.sort_values(
        "missing_percent",
        ascending=False
    ).head(10)
)

if "avg_position" in df.columns:
    print(
        "avg_position values equal to zero:",
        (df["avg_position"] == 0).sum()
    )
# Out:
# Dataset shape: (30000, 44)
# Duplicate grain: 0
#                               column  missing_count  missing_percent
# provider_used          provider_used          21438            71.46
# word_count                word_count           7699            25.66
# char_count                char_count           7699            25.66
# word_count_tier      word_count_tier           7699            25.66
# char_count_tier      char_count_tier           7699            25.66
# model_used                model_used           5733            19.11
# trend_pct                  trend_pct           3388            11.29
# competition_level  competition_level           2610             8.70
# search_volume          search_volume           2468             8.23
# cpc                              cpc           2468             8.23
# avg_position values equal to zero: 1205

# %% [markdown]
# ## Self-check
#
# Before you submit, confirm each line honestly:
#
# - [ ] Every section above is filled — markdown thinking AND the code that backs it
# - [ ] The notebook runs top to bottom with no errors (Runtime → Run all)
# - [ ] No client names, URLs, or private queries anywhere
# - [ ] My claims use careful words: observed, measured, directional, decision-support
# - [ ] Committed to my repo under `work/notebooks/` — then submit your repo URL on the card. Done.
